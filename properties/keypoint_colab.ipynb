# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n-pose.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="hand-keypoints.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.4.9  Python-3.10.11 torch-2.10.0+cpu CPU (Intel Core i5-1035G1 1.00GHz)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=hand-keypoints.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\github\Is_Attention_All_You_Need\runs\pose\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING Dataset 'hand-keypoints.yaml' images not found, missing path 'D:\github\datasets\hand-keypoints\images\val'
# Downloading https://ultralytics.com/assets/hand-keypoints.zip to 'D:\github\datasets\hand-keypoints.zip': 100% ━━━━━━━━━━━━ 369.0MB 2.7MB/s 2:15s 2:15<0.1s4s4
# Unzipping D:\github\datasets\hand-keypoints.zip to D:\github\datasets\hand-keypoints...: 100% ━━━━━━━━━━━━ 53543/53543 1.2Kfiles/s 45.5ss<0.1s
# Dataset download success  (183.1s), saved to D:\github\datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\disbr\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 600.9KB/s 1.3s 1.2s<0.1s
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[21, 3]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   1806720  ultralytics.nn.modules.head.Pose26           [1, [21, 3], 1, True, [64, 128, 256]]
# YOLO26n-pose summary: 363 layers, 4,069,344 parameters, 4,069,344 gradients, 12.1 GFLOPs
#
# Transferred 795/879 items from pretrained weights
# train: Fast image access  (ping: 0.10.0 ms, read: 42.916.9 MB/s, size: 12.4 KB)
# train: Scanning D:\github\datasets\hand-keypoints\labels\train... 18776 images, 0 backgrounds, 384 corrupt: 100% ━━━━━━━━━━━━ 18776/18776 1.0Kit/s 18.2s<0.0s
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00001070.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0378842]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00001886.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0113549]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00001887.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0120925]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0145646]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0178221]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002003.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0177777]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002143.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.058215  1.0215623]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002144.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.064052  1.0332886]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002202.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0108333 1.0111653 1.0115829]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002451.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0121104]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002454.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0229666]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002744.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0159454]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002745.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0333937]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002746.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0398711]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002747.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0452819]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002749.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0701249 1.0110065]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002751.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0657505 1.0112815]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002752.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0504898]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002754.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0313425]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002760.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0265807]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00002761.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0448866]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0210655 1.0371106 1.0142586 1.0292251 1.0175165]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003109.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0766226 1.0215404]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003111.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0615149]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003114.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0173419]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003162.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0111028 1.036798 ]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003164.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0237975 1.0124848 1.0397292 1.0100352 1.039561  1.0151614]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003372.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0101266]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003385.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0125335 1.0269886 1.0279286 1.0450985 1.0597193]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003387.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.022746  1.0413063 1.0242921 1.043689  1.0602849]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003388.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0187386 1.0366172 1.0212573 1.038971  1.0545769]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003390.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.020831  1.0405371 1.0225158 1.042324  1.060344 ]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003391.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0217468 1.0120403 1.0306264 1.0467039]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003392.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0159765 1.0274452 1.0465449]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003393.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0219244]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003434.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0763087 1.0129049]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003438.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0473061]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003439.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0105758]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003440.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0346699]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003442.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0179511]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003444.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0435983 1.010706 ]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003592.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0161511]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003593.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0154865 1.0172155 1.0174204]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003653.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0160301]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003654.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0179476]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003738.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0135425 1.0191842]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003739.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0168556 1.0192908 1.0201148 1.0166405]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003852.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0195918 1.0118294 1.0865511 1.1344006 1.1761467]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003853.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0499923 1.0787337 1.0921329 1.0357262 1.1215025 1.1520383 1.1742336]
# train: D:\github\datasets\hand-keypoints\images\train\IMG_00003854.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.
bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\github\Is_Attention_All_You_Need\runs\pose\train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss   rle_loss  Instances       Size
#       1/100         0G      1.975      10.92     0.7044       3.62    0.04307      27.22         28        640: 0% ──────────── 2/1150 4.4s/it 31.7s<1:24:0610
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 model = YOLO("yolo26n-pose.pt")  # load a pretrained model (recommended for training)
#       6 # Train the model
# ----> 7 results = model.train(data="hand-keypoints.yaml", epochs=100, imgsz=640)
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\engine\model.py:774, in Model.train(self, trainer, **kwargs)
#     771     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     772     self.model = self.trainer.model
# --> 774 self.trainer.train()
#     775 # Update model and cfg after training
#     776 if RANK in {-1, 0}:
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\engine\trainer.py:244, in BaseTrainer.train(self)
#     241         ddp_cleanup(self, str(file))
#     243 else:
# --> 244     self._do_train()
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\engine\trainer.py:433, in BaseTrainer._do_train(self)
#     431     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     432 else:
# --> 433     loss, self.loss_items = self.model(batch)
#     434 self.loss = loss.sum()
#     435 if RANK != -1:
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\tasks.py:141, in BaseModel.forward(self, x, *args, **kwargs)
#     128 """Perform forward pass of the model for either training or inference.
#     129
#     130 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)
#     138     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     139 """
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 141     return self.loss(x, *args, **kwargs)
#     142 return self.predict(x, *args, **kwargs)
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\tasks.py:332, in BaseModel.loss(self, batch, preds)
#     329     self.criterion = self.init_criterion()
#     331 if preds is None:
# --> 332     preds = self.forward(batch["img"])
#     333 return self.criterion(preds, batch)
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File D:\github\rubik_game\.venv\lib\site-packages\ultralytics\nn\modules\conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)
#      76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\conv.py:553, in Conv2d.forward(self, input)
#     552 def forward(self, input: Tensor) -> Tensor:
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
# File D:\github\rubik_game\.venv\lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#     535 if self.padding_mode != "zeros":
#     536     return F.conv2d(
#     537         F.pad(
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     545         self.groups,
#     546     )
# --> 548 return F.conv2d(
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     550 )
#
# KeyboardInterrupt:
